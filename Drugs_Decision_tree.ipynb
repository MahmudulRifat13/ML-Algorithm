# %% [markdown]
# <a href="https://colab.research.google.com/github/MahmudulRifat13/ML-Algorithm/blob/main/Drugs_Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drug200.csv')
df.head(10)
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY
# 5   22   F  NORMAL        HIGH    8.607  drugX
# 6   49   F  NORMAL        HIGH   16.275  drugY
# 7   41   M     LOW        HIGH   11.037  drugC
# 8   60   M  NORMAL        HIGH   15.171  drugY
# 9   43   M     LOW      NORMAL   19.368  drugY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
df['Sex']=LE.fit_transform(df['Sex'])
df['BP']=LE.fit_transform(df['BP'])
df['Cholesterol']=LE.fit_transform(df['Cholesterol'])
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   0            0   25.355  drugY
# 1     47    1   1            0   13.093  drugC
# 2     47    1   1            0   10.114  drugC
# 3     28    0   2            0    7.798  drugX
# 4     61    0   1            0   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   1            0   11.567  drugC
# 196   16    1   1            0   12.006  drugC
# 197   52    1   2            0    9.894  drugX
# 198   23    1   2            1   14.020  drugX
# 199   40    0   1            1   11.349  drugX
#
# [200 rows x 6 columns]

# %%
x=df.drop(['Drug'],axis=1)
x
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 0     23    0   0            0   25.355
# 1     47    1   1            0   13.093
# 2     47    1   1            0   10.114
# 3     28    0   2            0    7.798
# 4     61    0   1            0   18.043
# ..   ...  ...  ..          ...      ...
# 195   56    0   1            0   11.567
# 196   16    1   1            0   12.006
# 197   52    1   2            0    9.894
# 198   23    1   2            1   14.020
# 199   40    0   1            1   11.349
#
# [200 rows x 5 columns]

# %%
y=df['Drug']
y
# Out:
# 0      drugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      drugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
y_test
# Out:
# 191    drugA
# 138    drugB
# 109    drugY
# 50     drugY
# 77     drugY
# 46     drugA
# 179    drugY
# 15     drugY
# 129    drugX
# 156    drugA
# 9      drugY
# 5      drugX
# 25     drugY
# 157    drugY
# 11     drugY
# 193    drugC
# 197    drugX
# 40     drugY
# 69     drugY
# 145    drugX
# 41     drugB
# 83     drugA
# 160    drugX
# 52     drugY
# 98     drugY
# 30     drugX
# 63     drugX
# 112    drugX
# 121    drugY
# 64     drugB
# 167    drugX
# 174    drugA
# 162    drugX
# 82     drugC
# 186    drugB
# 24     drugY
# 12     drugY
# 87     drugY
# 3      drugX
# 42     drugY
# Name: Drug, dtype: object

# %%
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
dtc=tree.DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_prediction=dtc.predict(x_test)
test_data_accuracy=accuracy_score(y_test_prediction,y_test)
print('Accuracy : ',test_data_accuracy*100)
# Out:
# Accuracy :  97.5

# %%
dtc.predict([['34', '1', '2', '0' ,'35.355']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['drugY'], dtype=object)
